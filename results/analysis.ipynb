# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
projects = pd.read_json("projects.json")

# %%
all_files = glob.glob("*/*.json")
print(all_files)
# Out:
# ['jashkenas/underscore-2009-12-11.json', 'jashkenas/backbone-2015-12-29.json', 'jashkenas/underscore-2012-12-29.json', 'jashkenas/underscore-2015-12-18.json', 'jashkenas/backbone-2012-12-30.json', 'yarnpkg/yarn-2018-12-21.json', 'lodash/lodash-2018-12-27.json', 'lodash/lodash-2009-12-11.json', 'lodash/lodash-2015-12-30.json', 'lodash/lodash-2012-12-31.json', 'storybooks/storybook-2018-12-31.json', 'storybooks/storybook-2015-12-22.json', 'quilljs/quill-2012-12-18.json', 'quilljs/quill-2018-12-28.json', 'quilljs/quill-2015-12-31.json', 'caolan/async-2012-12-13.json', 'caolan/async-2015-12-30.json', 'caolan/async-2018-11-27.json', 'nodejs/node-2018-12-31.json', 'justjavac/awesome-wechat-weapp-2018-12-26.json', 'parcel-bundler/parcel-2018-12-31.json', 'mozilla/pdf.js-2015-12-30.json', 'mozilla/pdf.js-2018-12-31.json', 'mozilla/pdf.js-2012-12-28.json', 'styled-components/styled-components-2018-12-20.json', 'Kickball/awesome-selfhosted-2015-12-30.json', 'Kickball/awesome-selfhosted-2018-12
# ...

# %%
all_data_map = {f: pd.read_json(f) for f in all_files}
all_data_map.values()[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2880b2e113bb> in <module>
# ----> 1 all_data_map = {f: pd.read_json(f) for f in all_files}
#       2 all_data_map.values()[0]
#
# <ipython-input-5-2880b2e113bb> in <dictcomp>(.0)
# ----> 1 all_data_map = {f: pd.read_json(f) for f in all_files}
#       2 all_data_map.values()[0]
#
# /usr/local/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     527             )
#     528         else:
# ...

# %%
projects
# Out:
#       commits  contributors             createdAt  forks  \
# 0        1040           NaN  2014-11-01T23:52:32Z   1237
# 1        1149           NaN  2016-07-01T06:01:21Z   2179
# 2         254           NaN  2018-09-04T13:27:04Z   2094
# 3        8652           NaN  2014-08-18T19:11:54Z   8682
# 4         135           NaN  2015-11-21T19:05:09Z   5689
# 5         760           NaN  2017-08-07T16:36:47Z   1286
# 6        3746           NaN  2015-07-21T18:55:34Z   4105
# 7        6116           NaN  2014-10-16T18:29:12Z   1337
# 8       14792           NaN  2016-03-18T04:23:44Z   2415
# 9        1737           NaN  2015-03-26T19:58:06Z   2773
# 10       1155           NaN  2016-07-01T06:01:21Z   2182
# 11        254           NaN  2018-09-04T13:27:04Z   2065
# 12       2206           NaN  2016-01-19T17:39:16Z   2016
# 13        807           NaN  2012-05-13T03:27:22Z   5818
# 14        254           NaN  2018-09-04T13:27:04Z   2058
# ...
